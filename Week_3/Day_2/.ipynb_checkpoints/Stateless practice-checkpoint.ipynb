# %%
import matplotlib.pyplot as plt
import numpy as np 
from numpy import genfromtxt
import pandas as pd

# %%
# %matplotlib inline

# %%
data = pd.read_csv("global.csv",delimiter=',', header= 1)

# %%
data = data.drop(index = 140)
data
# Out:
#      Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0    1880 -0.17 -0.23 -0.08 -0.15 -0.08 -0.19  -.17  -.08  -.13  -.22  -.21
# 1    1881 -0.18 -0.13  0.04  0.07  0.08 -0.17   .02  -.02  -.14  -.20  -.17
# 2    1882  0.18  0.16  0.06 -0.15 -0.13 -0.21  -.15  -.05  -.13  -.22  -.15
# 3    1883 -0.27 -0.35 -0.11 -0.16 -0.16 -0.06  -.05  -.12  -.20  -.10  -.21
# 4    1884 -0.12 -0.06 -0.34 -0.39 -0.33 -0.34  -.31  -.26  -.26  -.24  -.32
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 135  2015  0.86  0.90  0.96  0.76  0.80  0.81   .74   .81   .85  1.09  1.06
# 136  2016  1.18  1.37  1.35  1.12  0.96  0.81   .85  1.02   .91   .89   .91
# 137  2017  1.02  1.14  1.17  0.95  0.92  0.73   .82   .87   .78   .91   .88
# 138  2018  0.82  0.85  0.90  0.90  0.83  0.79   .84   .76   .80  1.02   .83
# 139  2019  0.93  0.96  1.18  1.02  0.86  0.93   .95   .95   .93  1.02  1.00
#
#       Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0    -.16  -.15   ***   *** -0.10  -.15  -.19
# 1    -.05  -.07  -.08  -.16  0.06  -.06  -.17
# 2    -.34  -.09  -.07   .10 -0.07  -.14  -.17
# 3    -.10  -.16  -.18  -.32 -0.14  -.08  -.17
# 4    -.30  -.27  -.26  -.09 -0.35  -.30  -.27
# ..    ...   ...   ...   ...   ...   ...   ...
# 135  1.16   .90   .87   .85  0.84   .79  1.00
# 136   .86  1.02  1.04  1.23  1.14   .89   .90
# 137   .94   .93   .92  1.01  1.01   .81   .86
# 138   .92   .86   .86   .87  0.88   .80   .89
# 139  1.11   .99   .97   .94  1.02   .95   .99
#
# [140 rows x 19 columns]

# %%
years = data['Year'].astype(float)
jan = data['Jan'].astype(float)
aug = data['Aug'].astype(float)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15, 10))
ax.plot(years, jan, label='January', c='steelblue', ls='-', lw=3, marker='.', ms=7, mfc='#50514F', zorder=2)
ax.plot(years, aug, label='August', c='#F25F5C', ls='--', lw=3, zorder=2)
ax.axhline(0, lw=2, c='dimgray', ls='-')

# Setting legend
leg = ax.legend(loc=2, ncol=2, numpoints=1, fontsize=15, shadow=True)
leg.set_title(title='Month', prop = {'size':15})

# Axis labeling
ax.set_ylabel('Temperature\nAnomaly [$^o$C]', fontsize=20)
ax.set_xlabel('Year', fontsize=20)
ax.set_title('Yearly Temperature Anomaly Means for January and August', fontsize=24, y=1.05)

# Set and cahnge x-ticks
xticklabels = np.arange(1880, 2030, 10) 
ax.xaxis.set_ticks(xticklabels)
ax.set_xticklabels(xticklabels, fontsize=15, rotation=45)

# Set and change y-ticks
yticklabels = np.arange(-1.5, 2, 0.5)
ax.yaxis.set_ticks(yticklabels)
ax.set_yticklabels(yticklabels, fontsize=15)

# set limit of graph
ax.set_xlim([1880, 2020])
ax.set_ylim([-1.5, 1.5])

# The STYLE
ax.grid()
fig.patch.set_facecolor('lightsteelblue')

# %%
fig.savefig('stateless graph.png', dpi=150, bbox_inches='tight', facecolor=fig.get_facecolor())

# %%
fig.savefig('stateless.png')
