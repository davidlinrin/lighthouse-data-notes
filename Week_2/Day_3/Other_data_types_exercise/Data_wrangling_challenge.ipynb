# %% [markdown]
# # Pull and manipulate the API data
#
# The point of this exercise is to try data enrichment with data from external APIs. We are going to take data about road kills in Vermont in 2006 and try to figure out the weather during the accident and how many bars there are in the area. We will work with one api that has a Python wrapper library and one that does not.

# %% [markdown]
# ## Data
#
# The data for this exercise can be found [here](https://drive.google.com/file/d/1Nk-5RZC1yzJl7HzOJd3tzUjzMENSSdJJ/view?usp=sharing).
#
# Just run the cells below to get your data ready. Little help from us.

# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize  
from pprint import pprint
import xml.etree.ElementTree as ET
import requests 
import os
from re import search

# %%
mypath = '/mnt/d/lighthouse/lighthouse_data_notes/Week_2/Day_3/Other_data_types_exercise/'

# %%
data = pd.read_csv(mypath + "VT_VehicleAnimal_Collisions__2006.csv", 
                   na_values=['', ' '],
                   parse_dates=["DATE_"]
                  )
data["MONTH_"] = data.DATE_.dt.month
data.dropna(subset=['X', 'Y'], inplace=True)
# creation of variable with lon and lat together
data['ll'] = data['Y'].astype(str) + ',' + data['X'].astype(str)
print(data.shape)
# Out:
# (2244, 23)

# %%
data['date_string'] = data.DATE_.astype(str)

# %%
temp = data['date_string'].str.split("+",expand = True)

# %%
desired = temp[0]
desired = desired.str.replace(' ','T')
data['date'] = desired

# %%
data.head(2)
# Out:
#            X          Y  OBJECTID   MSRI_CODE                  MSRI_DESCR  \
# 4 -72.989424  42.833309         5        Deer                        Deer
# 5 -72.375495  43.581005         6  Deer RK AB  Deer, RoadKill, Adult Buck
#
#                       DATE_  TOWN_ID ROUTE_DES ROUTE  BEGIN_MM  ...  RT_NUM  \
# 4 2004-04-16 00:00:00+00:00    209.0      VT 8   008      0.35  ...     NaN
# 5 2005-03-22 00:00:00+00:00   1409.0      US 5   005      5.00  ...     NaN
#
#   DAY_ MONTH_ YEAR_  REP_AGEN  LOCATION  YEAR_INT  \
# 4  NaN    4.0  2004       AOT       NaN      2004
# 5  NaN    3.0  2005       AOT       NaN      2005
#
#                                       ll                date_string  \
# 4   42.83330874047745,-72.98942388725152  2004-04-16 00:00:00+00:00
# 5  43.581005107295645,-72.37549549789222  2005-03-22 00:00:00+00:00
#
#                   date
# 4  2004-04-16T00:00:00
# 5  2005-03-22T00:00:00
#
# [2 rows x 25 columns]

# %% [markdown]
# ## Foursquare API
#
# Foursquare API documentation is [here](https://developer.foursquare.com/)
#
# 1. Start a foursquare application and get your keys.
# 2. For each crash, pull number of of bars (category "Nightlife") in 5km radius.
# 3. Find a relationship between number of bars in the area and severity of the crash.
#
# Hints:
#
# * check out python package "foursquare"
# * what happens if the code fails?
# * what if you run out of requests? (check out [time](https://docs.python.org/2/library/time.html) package)

# %%
#set the keys
#Hotmail Key
foursquare_id = "FPZRTCK1PLAB5ZSBJBTVSAB0XLYWHVIFQOYS2OPQ1BDPKYSL"
foursquare_secret = "CEJPLMC55K4IGKB5XHTIZC2WPKQUTK3FRL1ZFBIVYLM44MOO"

#Google Key
#foursquare_id = "LHDPZ2TF3YUKTU4F4S5YY5BE3C20ZZRMQN3112X5OUWQMM1F"
#foursquare_secret = "VEV4YAZNK31DPPCOYCTZR3AFZWWEQTA3T5BB5HJEO05JJIX5"

# %%
# Install and load the library
import foursquare
from math import sin, cos, sqrt, atan2, radians
# Construct the client object
client = foursquare.Foursquare(client_id=foursquare_id, client_secret=foursquare_secret, redirect_uri='http://fondu.com/oauth/authorize')
# Build the authorization url for your app
auth_uri = client.oauth.auth_url()

# %%
category = client.venues.categories()
categories = json_normalize(category, record_path = 'categories')
nightlife_id = list(categories[categories['shortName'] == "Nightlife"]['id'])
nightlife_id = nightlife_id[0]
# Out:
# <ipython-input-14-2ded5d88077b>:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   categories = json_normalize(category, record_path = 'categories')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-2ded5d88077b> in <module>
#       1 category = client.venues.categories()
#       2 categories = json_normalize(category, record_path = 'categories')
# ----> 3 nightlife_id = list(nightlife[nightlife['shortName'] == "Nightlife"]['id'])
#       4 nightlife_id = nightlife_id[0]
#
# KeyError: 'shortName'

# %%
categories
# Out:
#                          id                         name  \
# 0  4d4b7104d754a06370d81259         Arts & Entertainment
# 1  4d4b7105d754a06372d81259         College & University
# 2  4d4b7105d754a06373d81259                        Event
# 3  4d4b7105d754a06374d81259                         Food
# 4  4d4b7105d754a06376d81259               Nightlife Spot
# 5  4d4b7105d754a06377d81259        Outdoors & Recreation
# 6  4d4b7105d754a06375d81259  Professional & Other Places
# 7  4e67e38e036454776db1fb3a                    Residence
# 8  4d4b7105d754a06378d81259               Shop & Service
# 9  4d4b7105d754a06379d81259           Travel & Transport
#
#                     pluralName              shortName  \
# 0         Arts & Entertainment   Arts & Entertainment
# 1      Colleges & Universities    College & Education
# 2                       Events                  Event
# 3                         Food                   Food
# 4              Nightlife Spots              Nightlife
# 5        Outdoors & Recreation  Outdoors & Recreation
# 6  Professional & Other Places           Professional
# 7                   Residences              Residence
# 8             Shops & Services                  Shops
# 9           Travel & Transport                 Travel
#
#                                           categories  \
# 0  [{'id': '56aa371be4b08b9a8d5734db', 'name': 'A...
# 1  [{'id': '4bf58dd8d48988d198941735', 'name': 'C...
# 2  [{'id': '52f2ab2ebcbc57f1066b8b3b', 'name': 'C...
# 3  [{'id': '503288ae91d4c4b30a586d67', 'name': 'A...
# 4  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...
# 5  [{'id': '4f4528bc4b90abdf24c9de85', 'name': 'A...
# 6  [{'id': '4e52d2d203646f7c19daa8ae', 'name': 'A...
# 7  [{'id': '5032891291d4c4b30a586d68', 'name': 'A...
# 8  [{'id': '52f2ab2ebcbc57f1066b8b56', 'name': 'A...
# 9  [{'id': '4bf58dd8d48988d1ed931735', 'name': 'A...
#
#                                          icon.prefix icon.suffix
# 0  https://ss3.4sqi.net/img/categories_v2/arts_en...        .png
# 1  https://ss3.4sqi.net/img/categories_v2/educati...        .png
# 2  https://ss3.4sqi.net/img/categories_v2/event/d...        .png
# 3  https://ss3.4sqi.net/img/categories_v2/food/de...        .png
# 4  https://ss3.4sqi.net/img/categories_v2/nightli...        .png
# 5  https://ss3.4sqi.net/img/categories_v2/parks_o...        .png
# 6  https://ss3.4sqi.net/img/categories_v2/buildin...        .png
# 7  https://ss3.4sqi.net/img/categories_v2/buildin...        .png
# 8  https://ss3.4sqi.net/img/categories_v2/shops/d...        .png
# 9  https://ss3.4sqi.net/img/categories_v2/travel/...        .png

# %%
def get_venues(ll):
    venues = client.venues.search(params = {'categoryId':nightlife_id, 'll' : ll, 'radius':'5000'})
    if len(venues) == 1:
        num_bars = 0
    else:
        num_bars = len(venues['venues'])
    return num_bars

#for i in range(len(ll_list)):
#    bars.append(get_venues(str(ll_list[i])))

# %%
# Create the function get_venues, 
# that will pull bars in the radius of 5km around the crash

res = client.venues.search(params={'query': 'Nightlife', 'll': '40.7233000,-74.0030000'})
res2 = client.venues.search(params={'query': 'bar', 'll': '40.7233000,-74.0030000'})
res3 = client.venues('5c56242b898bdc002c589118')
# EXAMPLE
# get_venues('48.146394, 17.107969')
# Out:
# {'venues': [{'id': '5cdc3b21c824ae002c24f8aa',
#    'name': 'NYC Office Of Nightlife',
#    'location': {'address': '1 Centre St',
#     'lat': 40.712938,
#     'lng': -74.003656,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.712938,
#       'lng': -74.003656}],
#     'distance': 1154,
#     'postalCode': '10007',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1 Centre St',
#      'New York, NY 10007',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d124941735',
#      'name': 'Office',
#      'pluralName': 'Offices',
#      'shortName': 'Office',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '52ad25e8498e65c5310e5da2',
#    'name': 'NYC Premier Nightlife',
#    'location': {'lat': 40.723024,
#     'lng': -73.984239,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.723024,
#       'lng': -73.984239}],
#     'distance': 1583,
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['New York, NY', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11f941735',
#      'name': 'Nightclub',
#      'pluralName': 'Nightclubs',
#      'shortName': 'Nightclub',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '51c2f99f498e89b83c83c05c',
#    'name': 'Nightlife',
#    'location': {'lat': 40.754680282740956,
#     'lng': -73.98150788115005,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.754680282740956,
#       'lng': -73.98150788115005}],
#     'distance': 3935,
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['New York, NY', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11a941735',
#      'name': 'Other Nightlife',
#      'pluralName': 'Other Nightlife',
#      'shortName': 'Nightlife',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '51094865e4b0756be45ce79d',
#    'name': 'SNAP Sports Nightlife And Pastime',
#    'location': {'lat': 40.73915,
#     'lng': -74.0011,
#     'labeledLatLngs': [{'label': 'display', 'lat': 40.73915, 'lng': -74.0011}],
#     'distance': 1771,
#     'postalCode': '10011',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['New York, NY 10011', 'United States']},
#    'categories': [],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '5a6df77486f4cc678d388601',
#    'name': 'Nightlife',
#    'location': {'address': '6701 Park Ave',
#     'crossStreet': '67th St',
#     'lat': 40.790908,
#     'lng': -74.004902,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.790908,
#       'lng': -74.004902}],
#     'distance': 7527,
#     'postalCode': '07093',
#     'cc': 'US',
#     'city': 'West New York',
#     'state': 'NJ',
#     'country': 'United States',
#     'formattedAddress': ['6701 Park Ave (67th St)',
#      'West New York, NJ 07093',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '55596b80498eccd4a6a32b3f',
#    'name': 'I AM NIGHTLIFE Hospitality & Entertainment Group',
#    'location': {'address': '572 Grand St',
#     'lat': 40.7138949,
#     'lng': -73.97890419999999,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.7138949,
#       'lng': -73.97890419999999},
#      {'label': 'entrance', 'lat': 40.714133, 'lng': -73.979089}],
#     'distance': 2286,
#     'postalCode': '10002',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['572 Grand St',
#      'New York, NY 10002',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d124941735',
#      'name': 'Office',
#      'pluralName': 'Offices',
#      'shortName': 'Office',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '129001989'},
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '4cfc40a0a9042c0f4757e20a',
#    'name': 'Nightlife strip club',
#    'location': {'address': '1654 broadway',
#     'crossStreet': '45th',
#     'lat': 40.7555615283013,
#     'lng': -73.97235939370941,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.7555615283013,
#       'lng': -73.97235939370941}],
#     'distance': 4424,
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1654 broadway (45th)',
#      'New York, NY',
#      'United States']},
#    'categories': [],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '4d3dfeefd625224b7abf9efa',
#    'name': 'Nightlife Productions',
#    'location': {'address': '545 W 45th St Ste 6H',
#     'lat': 40.762550354003906,
#     'lng': -73.99573516845703,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.762550354003906,
#       'lng': -73.99573516845703}],
#     'distance': 4412,
#     'postalCode': '10036',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['545 W 45th St Ste 6H',
#      'New York, NY 10036',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1f2931735',
#      'name': 'Performing Arts Venue',
#      'pluralName': 'Performing Arts Venues',
#      'shortName': 'Performing Arts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '5c79b258a8eb60002c98d99c',
#    'name': 'The New York Nightlife',
#    'location': {'address': '324 W 47th St',
#     'lat': 40.76081378,
#     'lng': -73.98891038,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.76081378,
#       'lng': -73.98891038}],
#     'distance': 4341,
#     'postalCode': '10036',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['324 W 47th St',
#      'New York, NY 10036',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d12d951735',
#      'name': 'Boat or Ferry',
#      'pluralName': 'Boats or Ferries',
#      'shortName': 'Boat / Ferry',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/boat_',
#       'suffix': '.png'},
#      'primary': True}],
#    'venuePage': {'id': '559325826'},
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '4c72efc4d944224b07110e29',
#    'name': 'NYC Nightlife',
#    'location': {'lat': 40.770705425063106,
#     'lng': -73.9850431900372,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.770705425063106,
#       'lng': -73.9850431900372}],
#     'distance': 5490,
#     'postalCode': '10023',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['New York, NY 10023', 'United States']},
#    'categories': [],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '59a20b67dd70c50f5221e0ed',
#    'name': 'NYC Nightlife Tours',
#    'location': {'address': '15 E 80th St',
#     'crossStreet': '5th ave',
#     'lat': 40.777459,
#     'lng': -73.962179,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.777459,
#       'lng': -73.962179},
#      {'label': 'entrance', 'lat': 40.777357, 'lng': -73.962248}],
#     'distance': 6942,
#     'postalCode': '10075',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['15 E 80th St (5th ave)',
#      'New York, NY 10075',
#      'United States']},
#    'categories': [{'id': '56aa371be4b08b9a8d573554',
#      'name': 'Entertainment Service',
#      'pluralName': 'Entertainment Services',
#      'shortName': 'Entertainment Service',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '55795a09498ec5c4a40f7299',
#    'name': 'The New York Night Life',
#    'location': {'address': '231 E 29th St Apt 3',
#     'lat': 40.74216079711914,
#     'lng': -73.97886657714844,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.74216079711914,
#       'lng': -73.97886657714844}],
#     'distance': 2924,
#     'postalCode': '10016',
#     'cc': 'US',
#     'city': 'New York',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['231 E 29th St Apt 3',
#      'New York, NY 10016',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1f6931735',
#      'name': 'General Travel',
#      'pluralName': 'General Travel',
#      'shortName': 'Travel',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '4efabfeff790731254e563f9',
#    'name': 'Night Life',
#    'location': {'crossStreet': 'McDonald Ave',
#     'lat': 40.600704440501964,
#     'lng': -73.97382869077786,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.600704440501964,
#       'lng': -73.97382869077786}],
#     'distance': 13867,
#     'postalCode': '11223',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['McDonald Ave',
#      'Brooklyn, NY 11223',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11f941735',
#      'name': 'Nightclub',
#      'pluralName': 'Nightclubs',
#      'shortName': 'Nightclub',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '50022077e4b07c8ae9477be1',
#    'name': 'Night life Bar',
#    'location': {'lat': 40.65466703957445,
#     'lng': -73.89469460268923,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.65466703957445,
#       'lng': -73.89469460268923}],
#     'distance': 11914,
#     'postalCode': '11207',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['Brooklyn, NY 11207', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d120941735',
#      'name': 'Karaoke Bar',
#      'pluralName': 'Karaoke Bars',
#      'shortName': 'Karaoke',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/karaoke_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '54f5f3a9498eefb548ce6d64',
#    'name': 'Night Life Transportation',
#    'location': {'address': '1169 E 55th St',
#     'lat': 40.628261,
#     'lng': -73.922733,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.628261,
#       'lng': -73.922733},
#      {'label': 'entrance', 'lat': 40.628255, 'lng': -73.922828}],
#     'distance': 12563,
#     'postalCode': '11234',
#     'cc': 'US',
#     'city': 'Brooklyn',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['1169 E 55th St',
#      'Brooklyn, NY 11234',
#      'United States']},
#    'categories': [{'id': '54541b70498ea6ccd0204bff',
#      'name': 'Transportation Service',
#      'pluralName': 'Transportation Services',
#      'shortName': 'Transportation Services',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/taxi_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '5ce976b0cabcff002c786002',
#    'name': 'Nightlife',
#    'location': {'address': '741 Van Emburgh Ave',
#     'crossStreet': 'Washington',
#     'lat': 41.000274658203125,
#     'lng': -74.07411193847656,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 41.000274658203125,
#       'lng': -74.07411193847656}],
#     'distance': 31408,
#     'postalCode': '07676',
#     'cc': 'US',
#     'city': 'Washington Township',
#     'state': 'NJ',
#     'country': 'United States',
#     'formattedAddress': ['741 Van Emburgh Ave (Washington)',
#      'Washington Township, NJ 07676',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11a941735',
#      'name': 'Other Nightlife',
#      'pluralName': 'Other Nightlife',
#      'shortName': 'Nightlife',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '5505fdc8498ec297b57c619e',
#    'name': 'Nightlife Recording Studio',
#    'location': {'address': '837 Willis Ave',
#     'lat': 40.766589,
#     'lng': -73.647471,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.766589,
#       'lng': -73.647471}],
#     'distance': 30369,
#     'postalCode': '11507',
#     'cc': 'US',
#     'city': 'Albertson',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['837 Willis Ave',
#      'Albertson, NY 11507',
#      'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b37',
#      'name': 'Recording Studio',
#      'pluralName': 'Recording Studios',
#      'shortName': 'Recording Studio',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_music_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '593310930336931d71bcc375',
#    'name': 'Nightlife',
#    'location': {'address': '231-233 Navajo Court',
#     'lat': 40.356518,
#     'lng': -74.21036,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.356518,
#       'lng': -74.21036}],
#     'distance': 44438,
#     'postalCode': '07751',
#     'cc': 'US',
#     'city': 'Marlboro',
#     'state': 'NJ',
#     'country': 'United States',
#     'formattedAddress': ['231-233 Navajo Court',
#      'Marlboro, NJ 07751',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d116941735',
#      'name': 'Bar',
#      'pluralName': 'Bars',
#      'shortName': 'Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '5c2c326712c8f0002c8010c1',
#    'name': 'Artizfacts Studio Gallery Hub (Artizfacts)',
#    'location': {'address': '3835 Sedgwick Ave',
#     'crossStreet': 'Stevenson',
#     'lat': 40.88270950317383,
#     'lng': -73.89530944824219,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.88270950317383,
#       'lng': -73.89530944824219}],
#     'distance': 19930,
#     'postalCode': '10463',
#     'cc': 'US',
#     'city': 'Bronx',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['3835 Sedgwick Ave (Stevenson)',
#      'Bronx, NY 10463',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e2931735',
#      'name': 'Art Gallery',
#      'pluralName': 'Art Galleries',
#      'shortName': 'Art Gallery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '4f327e7719836c91c7dd4055',
#    'name': 'Night Life Cafe',
#    'location': {'address': '165 Tuckahoe Rd',
#     'lat': 40.9552116394043,
#     'lng': -73.86325073242188,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.9552116394043,
#       'lng': -73.86325073242188}],
#     'distance': 28372,
#     'postalCode': '10710',
#     'cc': 'US',
#     'city': 'Yonkers',
#     'state': 'NY',
#     'country': 'United States',
#     'formattedAddress': ['165 Tuckahoe Rd',
#      'Yonkers, NY 10710',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False},
#   {'id': '4db5c9ad1e7248d135bbf633',
#    'name': 'AfterDark Night Life',
#    'location': {'address': '11 W Passaic St',
#     'lat': 40.909602,
#     'lng': -74.073854,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 40.909602,
#       'lng': -74.073854}],
#     'distance': 21580,
#     'postalCode': '07662',
#     'cc': 'US',
#     'city': 'Rochelle Park',
#     'state': 'NJ',
#     'country': 'United States',
#     'formattedAddress': ['11 W Passaic St',
#      'Rochelle Park, NJ 07662',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d124941735',
#      'name': 'Office',
#      'pluralName': 'Offices',
#      'shortName': 'Office',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'referralId': 'v-1596082593',
#    'hasPerk': False}]}

# %%
bar_dict ={}

for index, row in data.iterrows():
    
    lat_1 = row['Y']
    lon_1 = row['X']
    
    res = client.venues.search(params={'query': 'bar', 'll': row['ll']})
    
    for x in res['venues']:
        lat_2 = x['location']['lat']
        lon_2 = x['location']['lng']
        if len(x['categories']) < 1:
            continue
        else:
            if (x['categories'][0]['icon']['prefix'].find('nightlife')>0 and distance(lat_1,lon_1,lat_2,lon_2) < 5):
                if row['OBJECTID'] not in bar_dict:
                    bar_dict[row['OBJECTID']] = 1
                else:
                    bar_dict[row['OBJECTID']] += 1
# Out:
# Unknown error. meta: {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5f225b900070593f9d206009'}
# Unknown error. meta: {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5f225bd571a03639f39f6e55'}
# Unknown error. meta: {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5f225cbbf598007f30b894a6'}
# ---------------------------------------------------------------------------
# FoursquareException                       Traceback (most recent call last)
# <ipython-input-421-d0abc4f16d8b> in <module>
#       6     lon_1 = row['X']
#       7
# ----> 8     res = client.venues.search(params={'query': 'bar', 'll': row['ll']})
#       9
#      10     for x in res['venues']:
#
# /usr/local/lib/python3.8/dist-packages/foursquare/__init__.py in search(self, params, multi)
#     493         def search(self, params, multi=False):
#     494             """https://developer.foursquare.com/docs/venues/search"""
# --> 495             return self.GET("search", params, multi=multi)
#     496
#     497         def suggestcompletion(self, params, multi=False):
#
# /usr/local/lib/python3.8/dist-packages/foursquare/__init__.py in GET(self, path, *args, **kwargs)
#     345         def GET(self, path=None, *args, **kwargs):
#     346             """Use the requester to get the data"""
# --> 347             return self.requester.GET(self._expanded_path(path), *args, **kwargs)
#     348
#     349         def POST(self, path=None, *args, **kwargs):
#
# /usr/local/lib/python3.8/dist-packages/foursquare/__init__.py in GET(self, path, params, **kwargs)
#     278             params = self._enrich_params(params)
#     279             url = "{API_ENDPOINT}{path}".format(API_ENDPOINT=API_ENDPOINT, path=path)
# --> 280             result = _get(url, headers=headers, params=params, timeout=self.get_timeout)
#     281             self.rate_limit = result["headers"]["X-RateLimit-Limit"]
#     282             self.rate_remaining = result["headers"]["X-RateLimit-Remaining"]
#
# /usr/local/lib/python3.8/dist-packages/foursquare/__init__.py in _get(url, headers, params, timeout)
#     909                     timeout=timeout,
#     910                 )
# --> 911                 return _process_response(response)
#     912             except requests.exceptions.RequestException as e:
#     913                 _log_and_raise_exception("Error connecting with foursquare API", e)
#
# /usr/local/lib/python3.8/dist-packages/foursquare/__init__.py in _process_response(response)
#     955     if response.status_code == 200:
#     956         return {"headers": response.headers, "data": data}
# --> 957     return _raise_error_from_response(data)
#     958
#     959
#
# /usr/local/lib/python3.8/dist-packages/foursquare/__init__.py in _raise_error_from_response(data)
#     971             raise exc(meta.get("errorDetail"))
#     972         else:
# --> 973             _log_and_raise_exception("Unknown error. meta", meta)
#     974     else:
#     975         _log_and_raise_exception(
#
# /usr/local/lib/python3.8/dist-packages/foursquare/__init__.py in _log_and_raise_exception(msg, data, cls)
#     888     # as Sentry will properly group errors together by msg only
#     889     log.error(u"{0}: %s".format(msg), data)
# --> 890     raise cls(u"{0}: {1}".format(msg, data))
#     891
#     892
#
# FoursquareException: Unknown error. meta: {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '5f225cbbf598007f30b894a6'}

# %%
bar_dict
# Out:
# {}

# %%
print(len(res['venues'][2]['categories']))
print(len([]))
x
# Out:
# 1
# 0
# {'id': '5d19212f6d22da002f01f41a',
#  'name': 'Caldonia Spirits Distillery & Bar',
#  'location': {'address': '116 Gin Ln',
#   'lat': 44.2503,
#   'lng': -72.566933,
#   'labeledLatLngs': [{'label': 'display', 'lat': 44.2503, 'lng': -72.566933}],
#   'distance': 4267,
#   'postalCode': '05602',
#   'cc': 'US',
#   'city': 'Montpelier',
#   'state': 'VT',
#   'country': 'United States',
#   'formattedAddress': ['116 Gin Ln', 'Montpelier, VT 05602', 'United States']},
#  'categories': [{'id': '4e0e22f5a56208c4ea9a85a0',
#    'name': 'Distillery',
#    'pluralName': 'Distilleries',
#    'shortName': 'Distillery',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#     'suffix': '.png'},
#    'primary': True}],
#  'referralId': 'v-1596086694',
#  'hasPerk': False}

# %%
res['venues'][4]['categories'][0]['icon']['prefix']
# Out:
# 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_'

# %%
res['venues'][4]['categories'][0]['icon']['prefix'].find(' ')
# Out:
# -1

# %%
# Formula o Calculate the distance given lat and long
def distance(lat_1, lon_1, lat_2, lon_2):
    R = 6373.0
    lat1 = radians(lat_1)
    lon1 = radians(lon_1)
    lat2 = radians(lat_2)
    lon2 = radians(lon_2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    
    return(distance)

# %% [markdown]
# ## Virtual Crossing API
#
# Virtual Crossing API documentation is [here](https://www.visualcrossing.com/resources/documentation/)
#
# 1. Sign up for FREE api key if you haven't done that before.
# 2. For each crush, get the weather for the location and time.
# 3. Find a relationship between the weather and severity of the crash.
#
# Hints:
#
# * randomly sample only 500 or so (due to API limits), or pull weather only for each town, not every crash
# * for sending HTTP requests check out "requests" library [here](http://docs.python-requests.org/en/master/)

# %%
import requests
import time
api_key = "QJCNV1F8U9FVG6KYA82ITA3L7"
#url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history?&aggregateHours=24&startDateTime="+time+"&endDateTime="+time+"&unitGroup=metric&contentType=json&dayStartTime=0:0:00&dayEndTime=0:0:00&location="+location+"&key="+api_key

# %%
weather_dict ={}

for index, row in data.iterrows():
    location = row['ll']
    time = row['date']
    url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history?&aggregateHours=24&startDateTime="+time+"&endDateTime="+time+"&unitGroup=metric&contentType=json&dayStartTime=0:0:00&dayEndTime=0:0:00&location="+location+"&key="+api_key
    
    res=requests.get(url)
    result = res.json()
    
    weather_dict[location] = result['locations'][location]['values'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-265-2e98a58beb83> in <module>
#       9     result = res.json()
#      10
# ---> 11     weather_dict[location] = result['locations'][location]['values'][0]
#
# KeyError: 'locations'

# %%
weather_df = pd.DataFrame.from_dict(weather_dict)

# %%
weather_df = weather_df.T
#weather_df.head()

# %%
weather_dropped = weather_df.drop(columns=['wdir','visibility','datetime','wspd','precipcover','heatindex', 'weathertype','dew','snowdepth','sealevelpressure','wgust','info'])
#weather_dropped

# %%
weather_dropped = weather_dropped.reset_index()
weather_dropped = weather_dropped.rename(columns={'index':'ll'})

weather_temp = weather_dropped['datetimeStr'].str.split("T",expand = True)
#weather_temp  = weather_temp.iloc[:, :-1]
temp = weather_temp[1].str.split('-',expand = True)
weather_temp[1] = temp[0]
weather_temp['date_string'] = weather_temp[0] + "T" + weather_temp[1]
#weather_temp

# %%
weather_dropped['datetimeStr'] = weather_temp['date_string']

# %%
weather_dropped.head()
# Out:
#                                       ll  temp  maxt          datetimeStr  \
# 0   42.83330874047745,-72.98942388725152     6    14  2004-04-16T00:00:00
# 1  43.581005107295645,-72.37549549789222  23.4  30.6  2005-07-20T00:00:00
# 2    43.23502288333559,-72.8402568531839   1.2  12.1  2004-11-15T00:00:00
# 3   44.78300220380285,-72.83099079061695   1.6   3.5  2004-10-18T00:00:00
# 4   44.24232301744294,-72.51459452575021   7.1  16.1  2005-04-22T00:00:00
#
#   cloudcover  mint precip humidity              conditions windchill
# 0          0    -1      0    38.63                   Clear      -4.1
# 1       19.7  16.2      0    69.78                   Clear      None
# 2        1.2  -5.3      0    71.68                   Clear      -3.9
# 3         29  -3.6    0.8    77.48  Rain, Partially cloudy      -2.9
# 4        7.9    -4      0    46.22                   Clear       6.2

# %%
data.head()
# Out:
#            X          Y  OBJECTID   MSRI_CODE  \
# 4 -72.989424  42.833309         5        Deer
# 5 -72.375495  43.581005         6  Deer RK AB
# 6 -72.840257  43.235023         7     Lg Bird
# 7 -72.830991  44.783002         8       Otter
# 9 -72.514595  44.242323        10      Beaver
#
#                                   MSRI_DESCR                     DATE_  \
# 4                                       Deer 2004-04-16 00:00:00+00:00
# 5                 Deer, RoadKill, Adult Buck 2005-03-22 00:00:00+00:00
# 6  Large Bird (hawk, owl, turkey, waterfowl) 2004-11-15 00:00:00+00:00
# 7                                      Otter 2004-10-18 00:00:00+00:00
# 9                                     Beaver 2005-04-22 00:00:00+00:00
#
#    TOWN_ID ROUTE_DES ROUTE  BEGIN_MM  ...  RT_NUM DAY_ MONTH_ YEAR_  REP_AGEN  \
# 4    209.0      VT 8   008      0.35  ...     NaN  NaN    4.0  2004       AOT
# 5   1409.0      US 5   005      5.00  ...     NaN  NaN    3.0  2005       AOT
# 6   1310.0     VT 11   011      0.50  ...     NaN  NaN   11.0  2004       AOT
# 7    601.0     VT 36   036      1.00  ...     NaN  NaN   10.0  2004       AOT
# 9   1207.0      US 2   002      0.19  ...     NaN  NaN    4.0  2005       AOT
#
#    LOCATION  YEAR_INT                                     ll  \
# 4       NaN      2004   42.83330874047745,-72.98942388725152
# 5       NaN      2005  43.581005107295645,-72.37549549789222
# 6       NaN      2004    43.23502288333559,-72.8402568531839
# 7       NaN      2004   44.78300220380285,-72.83099079061695
# 9       NaN      2005   44.24232301744294,-72.51459452575021
#
#                  date_string                 date
# 4  2004-04-16 00:00:00+00:00  2004-04-16T00:00:00
# 5  2005-03-22 00:00:00+00:00  2005-03-22T00:00:00
# 6  2004-11-15 00:00:00+00:00  2004-11-15T00:00:00
# 7  2004-10-18 00:00:00+00:00  2004-10-18T00:00:00
# 9  2005-04-22 00:00:00+00:00  2005-04-22T00:00:00
#
# [5 rows x 25 columns]

# %%
merged = data.merge(weather_dropped,left_on=['ll','date'],right_on=['ll','datetimeStr'])

# %%
merged
# Out:
#              X          Y  OBJECTID   MSRI_CODE  \
# 0   -72.989424  42.833309         5        Deer
# 1   -72.840257  43.235023         7     Lg Bird
# 2   -72.830991  44.783002         8       Otter
# 3   -72.514595  44.242323        10      Beaver
# 4   -73.195801  43.433986        12     Lg Bird
# ..         ...        ...       ...         ...
# 174 -72.718631  44.390957       447       Otter
# 175 -73.103761  43.089094       451        Bear
# 176 -73.196794  44.969938       453       Other
# 177 -73.196794  44.969938      1008       Otter
# 178 -72.263910  44.550674       457  Deer RK UN
#
#                                     MSRI_DESCR                     DATE_  \
# 0                                         Deer 2004-04-16 00:00:00+00:00
# 1    Large Bird (hawk, owl, turkey, waterfowl) 2004-11-15 00:00:00+00:00
# 2                                        Otter 2004-10-18 00:00:00+00:00
# 3                                       Beaver 2005-04-22 00:00:00+00:00
# 4    Large Bird (hawk, owl, turkey, waterfowl) 2005-04-06 00:00:00+00:00
# ..                                         ...                       ...
# 174                                      Otter 2004-09-10 00:00:00+00:00
# 175                                       Bear 2005-10-24 00:00:00+00:00
# 176                                      Other 2004-09-24 00:00:00+00:00
# 177                                      Otter 2004-09-24 00:00:00+00:00
# 178                    Deer, RoadKill, Unknown 2004-12-28 00:00:00+00:00
#
#      TOWN_ID ROUTE_DES ROUTE  BEGIN_MM  ...                 date  temp  maxt  \
# 0      209.0      VT 8   008      0.35  ...  2004-04-16T00:00:00     6    14
# 1     1310.0     VT 11   011      0.50  ...  2004-11-15T00:00:00   1.2  12.1
# 2      601.0     VT 36   036      1.00  ...  2004-10-18T00:00:00   1.6   3.5
# 3     1207.0      US 2   002      0.19  ...  2005-04-22T00:00:00   7.1  16.1
# 4     1126.0     VT 30   030      2.80  ...  2005-04-06T00:00:00  11.1  18.9
# ..       ...       ...   ...       ...  ...                  ...   ...   ...
# 174   1218.0    VT 100   100      4.30  ...  2004-09-10T00:00:00  15.1  20.4
# 175    215.0      US 7   007      4.80  ...  2005-10-24T00:00:00   6.4   7.8
# 176    615.0     VT 78   078      1.20  ...  2004-09-24T00:00:00    10  17.9
# 177    615.0     VT 78   078      1.20  ...  2004-09-24T00:00:00    10  17.9
# 178   1009.0     VT 16   016      0.50  ...  2004-12-28T00:00:00 -10.2  -4.6
#
#              datetimeStr  cloudcover  mint  precip  humidity  \
# 0    2004-04-16T00:00:00           0    -1       0     38.63
# 1    2004-11-15T00:00:00         1.2  -5.3       0     71.68
# 2    2004-10-18T00:00:00          29  -3.6     0.8     77.48
# 3    2005-04-22T00:00:00         7.9    -4       0     46.22
# 4    2005-04-06T00:00:00        49.8   3.9       0     40.21
# ..                   ...         ...   ...     ...       ...
# 174  2004-09-10T00:00:00        82.5  11.3    0.06     85.75
# 175  2005-10-24T00:00:00         100   4.2       1     80.91
# 176  2004-09-24T00:00:00           0   3.3       0      73.2
# 177  2004-09-24T00:00:00           0   3.3       0      73.2
# 178  2004-12-28T00:00:00        52.5 -17.8       0     74.77
#
#                  conditions windchill
# 0                     Clear      -4.1
# 1                     Clear      -3.9
# 2    Rain, Partially cloudy      -2.9
# 3                     Clear       6.2
# 4          Partially cloudy       1.1
# ..                      ...       ...
# 174          Rain, Overcast      None
# 175          Rain, Overcast       4.4
# 176                   Clear         8
# 177                   Clear         8
# 178        Partially cloudy     -21.2
#
# [179 rows x 34 columns]

# %%
url = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history?&aggregateHours=24&startDateTime="+time+"&endDateTime="+time+"&unitGroup=metric&contentType=json&dayStartTime=0:0:00&dayEndTime=0:0:00&location="+location+"&key="+api_key

# %%
res=requests.get(url)
res

# %%
result = res.json()

# %%
result
# Out:
# {'errorCode': 999,
#  'sessionId': '',
#  'executionTime': -1,
#  'message': 'You have exceeded the maximum number of daily requests for your account. See https://www.visualcrossing.com/weather-data-editions for information about our plans and how to get more weather data for free.'}

# %%
result['locations'][location]['values']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-273-03fff2f9ace8> in <module>
# ----> 1 result['locations'][location]['values']
#
# KeyError: 'locations'

# %%
result['locations'][location]['values'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-310-4128f5845eee> in <module>
# ----> 1 result['locations'][location]['values'][0]
#
# KeyError: 'locations'

# %%
d = {}
d[location] = result['locations'][location]['values'][0]
d['asdasd'] = result['locations'][location]['values'][0]
