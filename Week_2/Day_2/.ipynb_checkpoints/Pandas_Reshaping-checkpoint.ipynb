# %%
import numpy as np
import pandas as pd

# %%
tuples = list(zip(*[
    ['bar', 'bar', 'baz', 'baz','foo', 'foo', 'qux', 'qux'],
    ['one', 'two', 'one', 'two','one', 'two', 'one', 'two']
    ]))
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])
df
# Out:
#                      A         B
# first second
# bar   one    -1.299674  0.153919
#       two     0.770295  0.529132
# baz   one    -0.937581 -0.242693
#       two     0.918523  0.806221
# foo   one     0.246690  0.646127
#       two    -1.391039 -1.428775
# qux   one     0.437127  1.921285
#       two    -1.150727  2.302448

# %%
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one    -1.299674  0.153919
#       two     0.770295  0.529132
# baz   one    -0.937581 -0.242693
#       two     0.918523  0.806221

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A   -1.299674
#                B    0.153919
#        two     A    0.770295
#                B    0.529132
# baz    one     A   -0.937581
#                B   -0.242693
#        two     A    0.918523
#                B    0.806221
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -1.299674  0.153919
#       two     0.770295  0.529132
# baz   one    -0.937581 -0.242693
#       two     0.918523  0.806221

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -1.299674  0.770295
#       B  0.153919  0.529132
# baz   A -0.937581  0.918523
#       B -0.242693  0.806221

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -1.299674 -0.937581
#        B  0.153919 -0.242693
# two    A  0.770295  0.918523
#        B  0.529132  0.806221

# %% [markdown]
# # Pivot tables in panda

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                       'B': ['A', 'B', 'C'] * 4,
                       'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                       'D': np.random.randn(12),
                       'E': np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.406437 -0.741485
# 1     one  B  foo -0.907781  0.090867
# 2     two  C  foo  0.408519 -0.010247
# 3   three  A  bar -0.216745  0.473165
# 4     one  B  bar -0.122491 -2.257375
# 5     one  C  bar  0.208668 -0.588268
# 6     two  A  foo -0.234125 -0.997414
# 7   three  B  foo  0.386822 -0.595968
# 8     one  C  foo -0.369947 -0.700711
# 9     one  A  bar  1.118280  0.886654
# 10    two  B  bar  0.624381 -0.020801
# 11  three  C  bar -1.604859  0.047734

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A  1.118280  0.406437
#       B -0.122491 -0.907781
#       C  0.208668 -0.369947
# three A -0.216745       NaN
#       B       NaN  0.386822
#       C -1.604859       NaN
# two   A       NaN -0.234125
#       B  0.624381       NaN
#       C       NaN  0.408519
