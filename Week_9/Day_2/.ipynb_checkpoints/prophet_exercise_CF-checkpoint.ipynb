# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# import pandas
import pandas as pd

# import matplotlib
import matplotlib.pyplot as plt

# import prophet
from fbprophet import Prophet

# %%
# load data
wmt = pd.read_csv('https://raw.githubusercontent.com/gumdropsteve/intro_to_prophet/master/data/WMT.csv')

# %% [markdown]
# * Explore the dataset

# %%
wmt.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close   Volume
# 0  1972-08-25  0.063477  0.064697  0.063477  0.064453   0.023768  2508800
# 1  1972-08-28  0.064453  0.064941  0.064209  0.064209   0.023678   972800
# 2  1972-08-29  0.063965  0.063965  0.063477  0.063477   0.023408  1945600
# 3  1972-08-30  0.063477  0.063477  0.062988  0.063477   0.023408   409600
# 4  1972-08-31  0.062988  0.062988  0.062500  0.062500   0.023047   870400

# %% [markdown]
# * use only `Date` and `Adj Close` columns

# %%
df=wmt[['Date','Adj Close']]

# %%
df.head()
# Out:
#          Date  Adj Close
# 0  1972-08-25   0.023768
# 1  1972-08-28   0.023678
# 2  1972-08-29   0.023408
# 3  1972-08-30   0.023408
# 4  1972-08-31   0.023047

# %% [markdown]
# * rename columns to fit Prophet naming convention

# %%
df = df.rename(columns={'Date': 'ds',
                        'Adj Close': 'y'})

# %% [markdown]
# * convert date to datetime

# %%
df['ds'] = pd.DatetimeIndex(df['ds'])
df.dtypes
# Out:
# ds    datetime64[ns]
# y            float64
# dtype: object

# %% [markdown]
# * plot time-series

# %%
# set the column as the index
df.set_index('ds', inplace=True)

# %%
df.shape
# Out:
# (11815, 1)

# %%
df.plot()

# %%
y=df['y'].resample('M').mean()

# %%
plt.plot(df['y'])
plt.plot(y, color='red')

# %%
df.shape
# Out:
# (11815, 1)

# %%
y.shape
# Out:
# (564,)

# %% [markdown]
# * instantiate Prophet

# %% [markdown]
# * fit model

# %%
# Python
m = Prophet()
m.fit(df.reset_index())
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# * forecast 365 values in future

# %%
# Python
future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
#               ds
# 12175 2020-06-27
# 12176 2020-06-28
# 12177 2020-06-29
# 12178 2020-06-30
# 12179 2020-07-01

# %% [markdown]
# * plot forecast

# %%
# Python
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#               ds       yhat  yhat_lower  yhat_upper
# 12175 2020-06-27  96.518241   91.646725  101.457293
# 12176 2020-06-28  96.520974   91.885070  101.295493
# 12177 2020-06-29  96.496342   91.703268  101.552215
# 12178 2020-06-30  96.516718   91.601924  101.044721
# 12179 2020-07-01  96.506340   91.803669  101.391325

# %%
# Python
fig1 = m.plot(forecast)

# %% [markdown]
# * plot components

# %%
# Python
fig2 = m.plot_components(forecast)

# %% [markdown]
# - Compare the Prophet prediction vs Arima. Use the last 7 values we have in the timeseries as ground truth.

# %%
y.shape
# Out:
# (564,)

# %%
y.head()
# Out:
# ds
# 1972-08-31    0.023462
# 1972-09-30    0.022363
# 1972-10-31    0.022180
# 1972-11-30    0.024380
# 1972-12-31    0.024592
# Freq: M, Name: y, dtype: float64

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
fig = plt.figure(figsize=(15,13))
result = seasonal_decompose(y, model='multiplicative',period=47)
result.plot()
pyplot.show()

# %% [raw]
# sum(y.isna())

# %%
from statsmodels.tsa.stattools import adfuller
def ADF_Stationarity_Test(timeseries,significance_level):
    '''prints adfuller test results
prints the conclusion stating whether timeseries is stationary based on the siginificance level (input parameter of function)'''
    X=pd.Series(timeseries).fillna(method='ffill')
    X=pd.Series(timeseries).fillna(method='bfill')
    result = adfuller(X)
    if result[1]<significance_level:
        explain=print("reject the null hypothesis: This dataset IS stationary, p value is",
                      result[1],". AD Fuller value is",result[0])
    else:
        explain=print("DO NOT reject the null hypothesis: This dataset IS NOT stationary, p value is",
                      result[1],". AD Fuller value is",result[0])
    return explain

# %%
ADF_Stationarity_Test(y,0.05)
# Out:
# DO NOT reject the null hypothesis: This dataset IS NOT stationary, p value is 1.0 . AD Fuller value is 2.8652942960578818

# %%
import numpy as np

# %%
y_trans=np.log(y)

# %%
ADF_Stationarity_Test(y_trans,0.05)
# Out:
# DO NOT reject the null hypothesis: This dataset IS NOT stationary, p value is 0.37722484473446694 . AD Fuller value is -1.806529471533443

# %% [markdown]
# # Difference the original, NOT the log - *** ONE OR THE OTHER

# %% [markdown]
# # Apply differencing

# %%
new_df=pd.DataFrame(y)

# %%
new_df['y_diff']=new_df['y']-new_df['y'].shift(1)

# %% [raw]
# new_df['y_add']

# %%
ADF_Stationarity_Test(new_df['y_diff'],0.05)
# Out:
# reject the null hypothesis: This dataset IS stationary, p value is 0.010775145354382867 . AD Fuller value is -3.4054301449581543

# %%
new_df['y_diff'].plot()

# %% [markdown]
# ## Finding Optimal p,d,q using gridsearch

# %%
import itertools

# %% [markdown]
# # Modelling off of the "differenced" series

# %%
#from the decomposition chart, anurag wanted to use 0-2 based on this (in his example)
#seasonal_pdq - Anurag used 12 - for months, if daily - use 30

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(new_df['y_diff'],
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:2106.3526154366746
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:2075.3662814214968
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:2417.7452525623507
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:2060.8310629175826
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:2078.1300875469897
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:2077.36459282493
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:2258.4428006379935
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:2069.260902162001
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:2056.323665649967
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:2025.9048709922813
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:2343.1130695726943
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:2014.088451904759
# /opt/anaconda3/envs/bootcamp_env/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:2031.7173983159744
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:2027.8359746358358
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:2192.3241778940464
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:2016.0884744481818
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:2309.9237737202125
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:2272.1653666238635
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:2572.2179687637354
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:2259.9644420922705
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:2277.6369604544625
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:2274.1562008888013
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:2415.290216648935
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:2261.963922864356
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:2093.9421793401743
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:2062.5855168285734
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:2418.3330294653015
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:2057.034835362533
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:2068.6451682026823
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:2064.4399116946815
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:2262.8786860356013
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:2066.6402194505345
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:2074.124357749051
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:2033.2271914556418
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:2354.7913974449357
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:2022.5018853287231
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:2033.6840560648632
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:2035.2271685607839
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:2187.55701805218
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:2024.5018981873582
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:2055.552792819591
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:2025.4534231509285
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:2344.9067035526687
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:2013.0410039481685
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:2028.3362321416762
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:2027.3984830391432
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:2181.6833807729745
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:2015.0409981109156
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:2257.476957104807
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:2214.8166720739555
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:2535.9667498337353
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:2203.9495507334705
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:2215.6468701736444
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:2216.8166368187
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:2366.297516996132
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:2205.9494624280546
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:2059.7264864906842
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:2028.944047490061
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:2355.220110637589
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:2022.8908720882948
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:2031.7385111256172
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:2031.4227404416579
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:2191.7369249329936
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:2024.8910011355056

# %% [markdown]
# for test_df['y_diff']: ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:2013.0410039481685
#
# ## for test_df['y_diff']: ARIMA(1, 1, 2)x(2, 1, 3, 12)12 - AIC:1940.91360815833

# %% [markdown]
# Looks like ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:2011.007001543766 has lowest AIC - so go with those params

# %%
mod = sm.tsa.statespace.SARIMAX(new_df['y_diff'],
                                order=(1, 1, 2),
                                seasonal_order=(2, 1, 3, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4326      0.060     -7.199      0.000      -0.550      -0.315
# ma.L1         -0.3201      0.054     -5.884      0.000      -0.427      -0.213
# ma.L2         -0.6936      0.055    -12.572      0.000      -0.802      -0.586
# ar.S.L12      -0.3483      0.253     -1.376      0.169      -0.844       0.148
# ar.S.L24      -0.4141      0.297     -1.396      0.163      -0.995       0.167
# ma.S.L12      -0.6624      0.250     -2.645      0.008      -1.153      -0.171
# ma.S.L24      -0.0593      0.337     -0.176      0.860      -0.719       0.600
# ma.S.L36      -0.2568      0.325     -0.790      0.430      -0.894       0.381
# sigma2         2.3202      0.177     13.127      0.000       1.974       2.667
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
y[495::]
# Out:
# ds
# 2013-11-30     68.228733
# 2013-12-31     68.415178
# 2014-01-31     66.504226
# 2014-02-28     64.352952
# 2014-03-31     65.778574
#                  ...
# 2019-03-31     97.532491
# 2019-04-30    100.366358
# 2019-05-31    101.212901
# 2019-06-30    108.235000
# 2019-07-31    111.110000
# Freq: M, Name: y, Length: 69, dtype: float64

# %%
type(pred)
# Out:
# statsmodels.tsa.statespace.mlemodel.PredictionResultsWrapper

# %% [markdown]
# # Within this plot - I'm re-transforming the predictions into the original scale (before differencing)

# %%
fig = plt.figure(figsize=(12,8))
pred = results.get_prediction(start=pd.to_datetime('2014-01-31'), dynamic=False)
pred_ci = pred.conf_int()

### Transform the predictions back to the same scale as before the differencing ###
pred_trans=pred.predicted_mean+new_df['y'].shift(1)
pred_low_trans=pred_ci['lower y_diff']+new_df['y']['2014':].shift(1)
pred_high_trans=pred_ci['upper y_diff']+new_df['y']['2014':].shift(1)

### Plot the transformed predictions against the observed ###
pred_trans['2014':].plot(color='salmon')
ax = y['2014':].plot(label='observed')
ax.fill_between(pred_ci.index,
                pred_low_trans,
                pred_high_trans, color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('ADJ_close')
plt.legend()
plt.show()

# %% [markdown]
# ## Use the last 7 values we have in the timeseries as ground truth

# %%
# ground truth
y[-7::]
# Out:
# ds
# 2019-01-31     94.792729
# 2019-02-28     96.738087
# 2019-03-31     97.532491
# 2019-04-30    100.366358
# 2019-05-31    101.212901
# 2019-06-30    108.235000
# 2019-07-31    111.110000
# Freq: M, Name: y, dtype: float64

# %%
yhat=forecast[['ds','yhat']]

# %%
# set the column as the index
yhat.set_index('ds', inplace=True)

# %%
proph_y=yhat.resample('M').mean()

# %%
proph_y[-19:-12]
# Out:
#                  yhat
# ds
# 2019-01-31  88.953408
# 2019-02-28  89.225161
# 2019-03-31  89.607373
# 2019-04-30  90.311264
# 2019-05-31  90.510900
# 2019-06-30  91.040099
# 2019-07-31  91.260080

# %%
pred_trans[-7::]
# Out:
# ds
# 2019-01-31     89.717544
# 2019-02-28     97.401655
# 2019-03-31     96.088736
# 2019-04-30     98.679393
# 2019-05-31    100.159439
# 2019-06-30    102.003589
# 2019-07-31    110.708906
# Freq: M, dtype: float64

# %% [markdown]
# ## ARIMA & PROPHET ERR

# %%
del Err_df

# %%
Err_df=pd.concat([y[-7::],pred_trans[-7::],proph_y[-19:-12]['yhat']],axis=1)

# %%
Err_df
# Out:
#                      y           0       yhat
# ds
# 2019-01-31   94.792729   89.717544  88.953408
# 2019-02-28   96.738087   97.401655  89.225161
# 2019-03-31   97.532491   96.088736  89.607373
# 2019-04-30  100.366358   98.679393  90.311264
# 2019-05-31  101.212901  100.159439  90.510900
# 2019-06-30  108.235000  102.003589  91.040099
# 2019-07-31  111.110000  110.708906  91.260080

# %%
Err_df=Err_df.rename(columns={0:'arima'})

# %%
Err_df['ar_err']=abs(Err_df['arima']-Err_df['y'])
Err_df['pr_err']=abs(Err_df['yhat']-Err_df['y'])

# %%
Err_df
# Out:
#                      y       arima       yhat    ar_err     pr_err
# ds
# 2019-01-31   94.792729   89.717544  88.953408  5.075185   5.839321
# 2019-02-28   96.738087   97.401655  89.225161  0.663568   7.512926
# 2019-03-31   97.532491   96.088736  89.607373  1.443756   7.925119
# 2019-04-30  100.366358   98.679393  90.311264  1.686964  10.055094
# 2019-05-31  101.212901  100.159439  90.510900  1.053462  10.702001
# 2019-06-30  108.235000  102.003589  91.040099  6.231411  17.194901
# 2019-07-31  111.110000  110.708906  91.260080  0.401095  19.849921

# %%
Err_df.sum()
# Out:
# y         709.987567
# arima     694.759263
# yhat      630.908283
# ar_err     16.555440
# pr_err     79.079284
# dtype: float64

# %% [markdown]
# # ARIMA has lower sum of errors over those 7 days

# %% [markdown]
# # Modelling without using the transformed model *** SAME RESULT

# %% [markdown]
# ## Finding Optimal p,d,q using gridsearch

# %% [raw]
# import itertools

# %%
#from the decomposition chart, anurag wanted to use 0-2 based on this (in his example)
#seasonality - use 12 - for months, if daily - use 30

# %% [raw]
# p = d = q = range(0, 2)
# pdq = list(itertools.product(p, d, q))
# seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
# print('Examples of parameter combinations for Seasonal ARIMA...')
# print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
# print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
# print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
# print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))

# %%
from statsmodels.tsa.arima_model import ARIMA
import statsmodels.api as sm

# %% [raw]
# for param in pdq:
#     for param_seasonal in seasonal_pdq:
#         try:
#             mod = sm.tsa.statespace.SARIMAX(y,
#                                             order=param,
#                                             seasonal_order=param_seasonal,
#                                             enforce_stationarity=False,
#                                             enforce_invertibility=False)
#             results = mod.fit()
#             print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
#         except:
#             continue

# %% [markdown]
# for test_df['y_diff']: ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:2013.0410039481685
#
# for test_df['y_diff']: ARIMA(1, 1, 2)x(2, 1, 3, 12)12 - AIC:1940.91360815833

# %% [markdown]
# Looks like ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:2011.007001543766 has lowest AIC - so go with those params

# %% [markdown]
# # Running the model on the UNTRANSFORMED (not differenced) data

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(0, 1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.3116      0.021     14.886      0.000       0.271       0.353
# ma.S.L12      -1.0380      0.029    -35.863      0.000      -1.095      -0.981
# sigma2         2.1780      0.106     20.526      0.000       1.970       2.386
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(16, 8))
plt.show()

# %%
y[500::]
# Out:
# ds
# 2014-04-30     68.050256
# 2014-05-31     68.013924
# 2014-06-30     66.888825
# 2014-07-31     67.065620
# 2014-08-31     66.087572
#                  ...
# 2019-03-31     97.532491
# 2019-04-30    100.366358
# 2019-05-31    101.212901
# 2019-06-30    108.235000
# 2019-07-31    111.110000
# Freq: M, Name: y, Length: 64, dtype: float64

# %%
pred_ci['lower y']
# Out:
# ds
# 2014-04-30     63.708789
# 2014-05-31     65.349924
# 2014-06-30     65.082944
# 2014-07-31     63.781181
# 2014-08-31     63.967929
#                  ...
# 2019-03-31     93.791111
# 2019-04-30     95.244670
# 2019-05-31     97.903906
# 2019-06-30     98.433456
# 2019-07-31    107.702976
# Freq: M, Name: lower y, Length: 64, dtype: float64

# %%
fig = plt.figure(figsize=(12,8))
pred = results.get_prediction(start=pd.to_datetime('2014-04-30'), dynamic=False)
pred_ci = pred.conf_int()
pred.predicted_mean.plot(color='black')
# pred_transformed=pred.predicted_mean.cumsum()
# pred_low_trans=pred_ci['lower y_diff'].cumsum()
# pred_high_trans=pred_ci['upper y_diff'].cumsum()
ax = y['2014':].plot(label='observed')

ax.fill_between(pred_ci.index,
                pred_ci['lower y'],
                pred_ci['upper y'], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('ADJ_close')
plt.legend()
plt.show()

# %% [markdown]
# ## Use the last 7 values we have in the timeseries as ground truth

# %%
# ground truth
y[-7::]
# Out:
# ds
# 2019-01-31     94.792729
# 2019-02-28     96.738087
# 2019-03-31     97.532491
# 2019-04-30    100.366358
# 2019-05-31    101.212901
# 2019-06-30    108.235000
# 2019-07-31    111.110000
# Freq: M, Name: y, dtype: float64

# %%
yhat=forecast[['ds','yhat']]

# %%
# set the column as the index
yhat.set_index('ds', inplace=True)

# %%
proph_y=yhat.resample('M').mean()

# %%
proph_y[-19:-12]
# Out:
#                  yhat
# ds
# 2019-01-31  88.953408
# 2019-02-28  89.225161
# 2019-03-31  89.607373
# 2019-04-30  90.311264
# 2019-05-31  90.510900
# 2019-06-30  91.040099
# 2019-07-31  91.260080

# %%
pred.predicted_mean[-7::]
# Out:
# ds
# 2019-01-31     88.646883
# 2019-02-28     96.584581
# 2019-03-31     96.797242
# 2019-04-30     98.250801
# 2019-05-31    100.910037
# 2019-06-30    101.439587
# 2019-07-31    110.709106
# Freq: M, dtype: float64

# %% [markdown]
# ## ARIMA ERR

# %%
Err_df=pd.concat([y[-7::],pred.predicted_mean[-7::],proph_y[-19:-12]['yhat']],axis=1)

# %%
Err_df=Err_df.rename(columns={0:'arima'})

# %%
Err_df['ar_err']=abs(Err_df['arima']-Err_df['y'])
Err_df['pr_err']=abs(Err_df['yhat']-Err_df['y'])

# %%
Err_df
# Out:
#                      y       arima       yhat    ar_err     pr_err
# ds
# 2019-01-31   94.792729   88.646883  88.953408  6.145845   5.839321
# 2019-02-28   96.738087   96.584581  89.225161  0.153507   7.512926
# 2019-03-31   97.532491   96.797242  89.607373  0.735250   7.925119
# 2019-04-30  100.366358   98.250801  90.311264  2.115557  10.055094
# 2019-05-31  101.212901  100.910037  90.510900  0.302864  10.702001
# 2019-06-30  108.235000  101.439587  91.040099  6.795413  17.194901
# 2019-07-31  111.110000  110.709106  91.260080  0.400894  19.849921

# %%
Err_df.sum()
# Out:
# y         709.987567
# arima     693.338238
# yhat      630.908283
# ar_err     16.649329
# pr_err     79.079284
# dtype: float64
